# %%
# config box
d = {"key":"val", "key1":"val1"}
# Out:
# The kernel failed to start as 'TypeAliasType' could not be imported from 'c:\Users\BIT\anaconda3\envs\kidney310\lib\site-packages\typing_extensions.py'.
#
# Click <a href='https://aka.ms/kernelFailuresModuleImportErrFromFile'>here</a> for more info.

# %%
d['key1']

# %%
d.key1

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val", "key1":"val1"})

# %%
d2.key1

# %%
type(d2)

# %%
type(d)

# %%
# ensure annotations 

def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)

# %%
get_prodict(x=2, y="3")

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_prodict(x:int, y:int) -> int:
    return x*y

# %%
get_prodict(x=2, y=3)

# %%
get_prodict(x=2, y="3")

# %% [markdown]
# ## Donwload data from gdrive

# %%
import gdown

# %%
url="https://drive.google.com/file/d/1PeMVccOhWpCcX4ZL3I9-qJJ1LgiEaWPm/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
